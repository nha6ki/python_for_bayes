# %%
import numpy as np
import scipy.stats as st

# %%
# %run -i ../python/pybayes_conjugate_poisson.py
# Out:
#               平均    中央値    最頻値   標準偏差  信用区間（下限）  信用区間（上限）  HPD区間（下限）  HPD区間（上限）
# $\lambda$ 2.9020 2.8954 2.8824 0.2385    2.4533    3.3878     2.4409     3.3740

# %%
# %run -i ../python/pybayes_conjugate_gaussian.py
# Out:
#                   平均    中央値    最頻値   標準偏差  信用区間（下限）  信用区間（上限）  HPD区間（下限）  HPD区間（上限）
# 平均 $\mu$      1.0043 1.0043 1.0043 0.2714    0.4704    1.5382     0.4704     1.5382
# 分散 $\sigma^2$ 3.6975 3.6066 3.4380 0.7322    2.5325    5.3839     2.4024     5.1650

# %%
# %run -i ../python/pybayes_conjugate_regression.py
# Out:
#                   平均    中央値    最頻値   標準偏差  信用区間（下限）  信用区間（上限）  HPD区間（下限）  HPD区間（上限）
# 切片 $\alpha$   0.9990 0.9990 0.9990 0.1082    0.7861    1.2119     0.7861     1.2119
# 傾き $\beta$    2.0032 2.0032 2.0032 0.1113    1.7843    2.2222     1.7843     2.2222
# 分散 $\sigma^2$ 0.5872 0.5728 0.5460 0.1163    0.4022    0.8551     0.3815     0.8203

# %%
# %run -i ../python/pybayes_poisson_gamma.py
# %run -i ../python/pybayes_gaussian_distribution.py
# %run -i ../python/pybayes_invgamma_t.py
